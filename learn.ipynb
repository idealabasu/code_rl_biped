# %%
import gymnasium as gym
from my_envs.biped import BipedEnv
from stable_baselines3 import PPO
import numpy
import matplotlib.pyplot as plt
import datetime
import torch

# %%
now = datetime.datetime.now()
run_prefix = datetime.datetime.strftime(now, '%Y-%m-%d-%H-%M')

# %%
env = gym.make('biped',render_mode='none',max_episode_steps=BipedEnv.max_steps)
model = PPO(
    "MlpPolicy", env, seed=3,
    # n_steps=4096,
    # policy_kwargs={'activation_fn':torch.nn.ELU},
    verbose=1,tensorboard_log='log/'+run_prefix+'/'
)
model.learn(total_timesteps=20000,tb_log_name='_run_1')
model.save(run_prefix+'_run_1.zip')
env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to log/2024-10-18-12-20/run_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -25.3    |
# | time/              |          |
# |    fps             | 1067     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -26.1       |
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008982245 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | -1.5695467  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0621      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00877    |
# |    std                  | 0.976       |
# |    value_loss           | 0.141       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -27.6       |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008537048 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.15305424  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.094       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00779    |
# |    std                  | 0.952       |
# |    value_loss           | 0.165       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | -27.2      |
# | time/                   |            |
# |    fps                  | 707        |
# |    iterations           | 4          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00649583 |
# |    clip_fraction        | 0.054      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.72      |
# |    explained_variance   | 0.48558408 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0538     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00565   |
# |    std                  | 0.935      |
# |    value_loss           | 0.15       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -26.8       |
# | time/                   |             |
# |    fps                  | 674         |
# |    iterations           | 5           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006715632 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.7372783   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0227      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0072     |
# |    std                  | 0.915       |
# |    value_loss           | 0.0991      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -25.8        |
# | time/                   |              |
# |    fps                  | 686          |
# |    iterations           | 6            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0087407185 |
# |    clip_fraction        | 0.0787       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.7553508    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00902      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00826     |
# |    std                  | 0.888        |
# |    value_loss           | 0.102        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 7           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009726087 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.7492468   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00816     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00973    |
# |    std                  | 0.872       |
# |    value_loss           | 0.0751      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -24         |
# | time/                   |             |
# |    fps                  | 697         |
# |    iterations           | 8           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006529197 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.5830486   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0198      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00602    |
# |    std                  | 0.844       |
# |    value_loss           | 0.0452      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -23.5       |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 9           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010124531 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | 0.06124723  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0544      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0084     |
# |    std                  | 0.817       |
# |    value_loss           | 0.116       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -23.2       |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 10          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014651575 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.39       |
# |    explained_variance   | 0.5319058   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0249      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.79        |
# |    value_loss           | 0.0605      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -23.4        |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 11           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0059206453 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.43090522   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0423       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00358     |
# |    std                  | 0.78         |
# |    value_loss           | 0.0967       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -22.7        |
# | time/                   |              |
# |    fps                  | 704          |
# |    iterations           | 12           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0069714664 |
# |    clip_fraction        | 0.0785       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.5917692    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0536       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00606     |
# |    std                  | 0.771        |
# |    value_loss           | 0.132        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -22.2       |
# | time/                   |             |
# |    fps                  | 699         |
# |    iterations           | 13          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010900808 |
# |    clip_fraction        | 0.0822      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.7729942   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0015      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.742       |
# |    value_loss           | 0.0701      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -21.7       |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 14          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008276724 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.7058152   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0264      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00803    |
# |    std                  | 0.717       |
# |    value_loss           | 0.0823      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | -21.1      |
# | time/                   |            |
# |    fps                  | 701        |
# |    iterations           | 15         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00591514 |
# |    clip_fraction        | 0.0662     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.16      |
# |    explained_variance   | 0.6124934  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0527     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00603   |
# |    std                  | 0.708      |
# |    value_loss           | 0.0738     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -21.1       |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 16          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008734072 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.46738553  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00242     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00995    |
# |    std                  | 0.69        |
# |    value_loss           | 0.0578      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -20.7        |
# | time/                   |              |
# |    fps                  | 702          |
# |    iterations           | 17           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0059169196 |
# |    clip_fraction        | 0.0754       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.38665348   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0272       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00799     |
# |    std                  | 0.678        |
# |    value_loss           | 0.092        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -20.5       |
# | time/                   |             |
# |    fps                  | 699         |
# |    iterations           | 18          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008276708 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.6814383   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0132      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00828    |
# |    std                  | 0.664       |
# |    value_loss           | 0.0856      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -20.2       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 19          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010092953 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.64521337  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0548      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.651       |
# |    value_loss           | 0.192       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 497        |
# |    ep_rew_mean          | -21.2      |
# | time/                   |            |
# |    fps                  | 699        |
# |    iterations           | 20         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.0092595  |
# |    clip_fraction        | 0.0835     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.95      |
# |    explained_variance   | -0.9021456 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.05       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0105    |
# |    std                  | 0.633      |
# |    value_loss           | 0.159      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 498          |
# |    ep_rew_mean          | -22.2        |
# | time/                   |              |
# |    fps                  | 702          |
# |    iterations           | 21           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0074941386 |
# |    clip_fraction        | 0.0768       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | -0.6637552   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.136        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00706     |
# |    std                  | 0.63         |
# |    value_loss           | 0.433        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 498          |
# |    ep_rew_mean          | -22.8        |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 22           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0040616523 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.49809068   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.283        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00168     |
# |    std                  | 0.628        |
# |    value_loss           | 0.685        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 498          |
# |    ep_rew_mean          | -22.4        |
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 23           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0064999056 |
# |    clip_fraction        | 0.0939       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.73347247   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.171        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00722     |
# |    std                  | 0.632        |
# |    value_loss           | 0.351        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 498         |
# |    ep_rew_mean          | -22         |
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 24          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010781447 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.6329054   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0474      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.626       |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 498         |
# |    ep_rew_mean          | -22         |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 25          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014902256 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.65301234  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0293      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.617       |
# |    value_loss           | 0.0777      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 498         |
# |    ep_rew_mean          | -21.8       |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 26          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.00531828  |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | -0.05648923 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0348      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00511    |
# |    std                  | 0.619       |
# |    value_loss           | 0.22        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 498          |
# |    ep_rew_mean          | -21.1        |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 27           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0036759393 |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.6347203    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0312       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00353     |
# |    std                  | 0.613        |
# |    value_loss           | 0.0802       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 497          |
# |    ep_rew_mean          | -20.9        |
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 28           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0050221356 |
# |    clip_fraction        | 0.0534       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.7240407    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0318       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00446     |
# |    std                  | 0.612        |
# |    value_loss           | 0.0674       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -20.2       |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 29          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.007120286 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.21483552  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0777      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00411    |
# |    std                  | 0.605       |
# |    value_loss           | 0.167       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -19.6       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 30          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009167083 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.70862293  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0509      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.597       |
# |    value_loss           | 0.0545      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -19         |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 31          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009118388 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.64397055  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00259    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.007      |
# |    std                  | 0.585       |
# |    value_loss           | 0.0371      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -18.5       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 32          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009167163 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.69673085  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00648    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00565    |
# |    std                  | 0.568       |
# |    value_loss           | 0.029       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 497          |
# |    ep_rew_mean          | -17.9        |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 33           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0061096684 |
# |    clip_fraction        | 0.0569       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.63659513   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00994      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00584     |
# |    std                  | 0.553        |
# |    value_loss           | 0.0255       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -17.4       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 34          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008838117 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.7264297   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00637     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.539       |
# |    value_loss           | 0.0396      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -16.5       |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 35          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008146083 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.6619766   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0369      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00745    |
# |    std                  | 0.531       |
# |    value_loss           | 0.042       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -15.8       |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 36          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.006105781 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.69552124  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00909     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00557    |
# |    std                  | 0.52        |
# |    value_loss           | 0.045       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -15.3       |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 37          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006728435 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.6375643   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0554      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00513    |
# |    std                  | 0.51        |
# |    value_loss           | 0.0868      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -14.7       |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 38          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008564992 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.63736826  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00737    |
# |    std                  | 0.497       |
# |    value_loss           | 0.0527      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 497          |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 39           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0060234815 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.6634089    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0064       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00474     |
# |    std                  | 0.485        |
# |    value_loss           | 0.0422       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -13.5       |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 40          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009587034 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.7294767   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00739    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.475       |
# |    value_loss           | 0.0411      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -13         |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 41          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.005857324 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.71023613  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0438      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00323    |
# |    std                  | 0.469       |
# |    value_loss           | 0.0954      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 42          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007945368 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.7831872   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00425     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00733    |
# |    std                  | 0.459       |
# |    value_loss           | 0.0546      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -11.6       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 43          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005577708 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.7765536   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0222      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00669    |
# |    std                  | 0.456       |
# |    value_loss           | 0.0617      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -9.83       |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 44          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008094411 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.7892378   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0084      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00946    |
# |    std                  | 0.447       |
# |    value_loss           | 0.0495      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 499         |
# |    ep_rew_mean          | -7.98       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 45          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007089659 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.7351091   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0268      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00226    |
# |    std                  | 0.442       |
# |    value_loss           | 0.0632      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 499        |
# |    ep_rew_mean          | -6.62      |
# | time/                   |            |
# |    fps                  | 740        |
# |    iterations           | 46         |
# |    time_elapsed         | 127        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.00560476 |
# |    clip_fraction        | 0.0538     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.19      |
# |    explained_variance   | 0.74770397 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0189     |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0039    |
# |    std                  | 0.435      |
# |    value_loss           | 0.0424     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 499        |
# |    ep_rew_mean          | -5.12      |
# | time/                   |            |
# |    fps                  | 741        |
# |    iterations           | 47         |
# |    time_elapsed         | 129        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.00682797 |
# |    clip_fraction        | 0.0992     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.7673304  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00722    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00559   |
# |    std                  | 0.433      |
# |    value_loss           | 0.042      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 499         |
# |    ep_rew_mean          | -4.47       |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 48          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006937932 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.73059726  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00232     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00724    |
# |    std                  | 0.427       |
# |    value_loss           | 0.037       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 499        |
# |    ep_rew_mean          | -3.55      |
# | time/                   |            |
# |    fps                  | 742        |
# |    iterations           | 49         |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.00873046 |
# |    clip_fraction        | 0.084      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | 0.79379267 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00492    |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00436   |
# |    std                  | 0.42       |
# |    value_loss           | 0.0375     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 499          |
# |    ep_rew_mean          | -2.13        |
# | time/                   |              |
# |    fps                  | 741          |
# |    iterations           | 50           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0072721546 |
# |    clip_fraction        | 0.0862       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.81660694   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00421      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.004       |
# |    std                  | 0.414        |
# |    value_loss           | 0.0419       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 499         |
# |    ep_rew_mean          | -1.12       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 51          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008654195 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.7096575   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00435     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00366    |
# |    std                  | 0.408       |
# |    value_loss           | 0.0418      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 499         |
# |    ep_rew_mean          | -0.244      |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 52          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.007673011 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.71868503  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0291      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00596    |
# |    std                  | 0.405       |
# |    value_loss           | 0.0385      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 0.796        |
# | time/                   |              |
# |    fps                  | 738          |
# ...
# |    entropy_loss         | 1.57        |
# |    explained_variance   | 0.84385663  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00594     |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.000732   |
# |    std                  | 0.11        |
# |    value_loss           | 0.0055      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 229         |
# |    time_elapsed         | 598         |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.011705432 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.59        |
# |    explained_variance   | 0.82736826  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00462    |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | 0.00081     |
# |    std                  | 0.109       |
# |    value_loss           | 0.00711     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 230         |
# |    time_elapsed         | 601         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.008334218 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.58        |
# |    explained_variance   | 0.7435915   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0136      |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | 0.00333     |
# |    std                  | 0.11        |
# |    value_loss           | 0.012       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 231         |
# |    time_elapsed         | 603         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.018135179 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.59        |
# |    explained_variance   | 0.8150012   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00295     |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.000144   |
# |    std                  | 0.108       |
# |    value_loss           | 0.0059      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 232         |
# |    time_elapsed         | 606         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.012392145 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.62        |
# |    explained_variance   | 0.81054765  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00574     |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | 0.000561    |
# |    std                  | 0.107       |
# |    value_loss           | 0.0074      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 233         |
# |    time_elapsed         | 608         |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.013069273 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.64        |
# |    explained_variance   | 0.82417756  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0211      |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | 0.00142     |
# |    std                  | 0.106       |
# |    value_loss           | 0.00713     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 234         |
# |    time_elapsed         | 611         |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.010603787 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.66        |
# |    explained_variance   | 0.7773587   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0153      |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | 0.000191    |
# |    std                  | 0.105       |
# |    value_loss           | 0.0077      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 235         |
# |    time_elapsed         | 613         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.009468367 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.68        |
# |    explained_variance   | 0.835972    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0653      |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | 0.00297     |
# |    std                  | 0.104       |
# |    value_loss           | 0.00538     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 236         |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.014057104 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.7         |
# |    explained_variance   | 0.85424113  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00733     |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | 0.00326     |
# |    std                  | 0.103       |
# |    value_loss           | 0.00452     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 237         |
# |    time_elapsed         | 618         |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.018279336 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.7         |
# |    explained_variance   | 0.79911524  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | 0.0012      |
# |    std                  | 0.104       |
# |    value_loss           | 0.00869     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 238         |
# |    time_elapsed         | 620         |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.010246463 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.7         |
# |    explained_variance   | 0.79699427  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00276     |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | 0.00064     |
# |    std                  | 0.103       |
# |    value_loss           | 0.00524     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 239         |
# |    time_elapsed         | 623         |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.010559236 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.7         |
# |    explained_variance   | 0.8559529   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | 5.94e-05    |
# |    std                  | 0.103       |
# |    value_loss           | 0.00503     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | 19.2       |
# | time/                   |            |
# |    fps                  | 784        |
# |    iterations           | 240        |
# |    time_elapsed         | 626        |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.01219181 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.7        |
# |    explained_variance   | 0.84131086 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0243    |
# |    n_updates            | 2390       |
# |    policy_gradient_loss | -0.0031    |
# |    std                  | 0.103      |
# |    value_loss           | 0.00521    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 241         |
# |    time_elapsed         | 628         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.011843976 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.71        |
# |    explained_variance   | 0.8049784   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0204      |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | 0.000288    |
# |    std                  | 0.103       |
# |    value_loss           | 0.00742     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | 19.3       |
# | time/                   |            |
# |    fps                  | 784        |
# |    iterations           | 242        |
# |    time_elapsed         | 631        |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.01871813 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.71       |
# |    explained_variance   | 0.77361405 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0229     |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | 0.000328   |
# |    std                  | 0.103      |
# |    value_loss           | 0.00723    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | 19.2       |
# | time/                   |            |
# |    fps                  | 784        |
# |    iterations           | 243        |
# |    time_elapsed         | 634        |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.00988808 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.7        |
# |    explained_variance   | 0.7664418  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0157    |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | 0.00216    |
# |    std                  | 0.103      |
# |    value_loss           | 0.0103     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 244         |
# |    time_elapsed         | 637         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.014461761 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.7         |
# |    explained_variance   | 0.80270535  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.000669   |
# |    std                  | 0.104       |
# |    value_loss           | 0.00694     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 500       |
# |    ep_rew_mean          | 19.2      |
# | time/                   |           |
# |    fps                  | 783       |
# |    iterations           | 245       |
# |    time_elapsed         | 640       |
# |    total_timesteps      | 501760    |
# | train/                  |           |
# |    approx_kl            | 0.0151815 |
# |    clip_fraction        | 0.145     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.7       |
# |    explained_variance   | 0.8518936 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0503    |
# |    n_updates            | 2440      |
# |    policy_gradient_loss | 0.003     |
# |    std                  | 0.103     |
# |    value_loss           | 0.00567   |
# ---------------------------------------

# %%
env = gym.make('biped',render_mode='none',max_episode_steps=BipedEnv.max_steps)
model = PPO.load(run_prefix+'_run_1.zip', env=env)
model.learn(total_timesteps=500000,tb_log_name="_run_2", reset_num_timesteps=False)
model.save(run_prefix+'-2.zip')
env.close()
